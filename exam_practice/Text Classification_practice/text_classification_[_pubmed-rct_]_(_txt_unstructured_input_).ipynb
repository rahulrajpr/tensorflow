# %% [markdown]
# ### Set up the Environment

# %%
from IPython.core.display import clear_output
# !wget https://raw.githubusercontent.com/rahulrajpr/references/main/requirements_tf_cert_exam.txt
clear_output()

# %%
# !wget https://raw.githubusercontent.com/rahulrajpr/references/main/helper_functions.py
clear_output()

# %%
# !pip install -r requirements_tf_cert_exam.txt
# !pip install split_folders
clear_output()

# %% [markdown]
# > Import Libraries

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib as plt
import scipy
import warnings
warnings.filterwarnings('ignore')
import os
import random

# %% [markdown]
# > Check the versions of the library

# %%
print(f'tensorflow version : {tf.__version__}')
print(f'pandas version : {pd.__version__}')
print(f'numpy version : {np.__version__}')
print(f'scipy version : {scipy.__version__}')
# Out:
# tensorflow version : 2.10.0
# pandas version : 1.4.2
# numpy version : 1.22.4
# scipy version : 1.7.3

# %% [markdown]
# ### Download the DataSet

# %%
# !git clone https://github.com/Franck-Dernoncourt/pubmed-rct.git
# !ls pubmed-rct
# Out:
# Cloning into 'pubmed-rct'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 33 (delta 5), reused 5 (delta 5), pack-reused 25
# Unpacking objects: 100% (33/33), 177.08 MiB | 4.74 MiB/s, done.
# Updating files: 100% (13/13), done.
# PubMed_200k_RCT
# PubMed_200k_RCT_numbers_replaced_with_at_sign
# PubMed_20k_RCT
# PubMed_20k_RCT_numbers_replaced_with_at_sign
# README.md

# %%
# !ls pubmed-rct/PubMed_200k_RCT_numbers_replaced_with_at_sign/
# Out:
# dev.txt  test.txt  train.zip

# %%
train_zip_dir = 'pubmed-rct/PubMed_200k_RCT_numbers_replaced_with_at_sign/train.zip'

# %%
from helper_functions import unzip_untar_data

# %%
unzip_untar_data(train_zip_dir)
# Out:
# File extension : .zip
# File extracting.......
# Completed successfully

# %%
train_dir = 'train.txt'
val_dir = 'pubmed-rct/PubMed_200k_RCT_numbers_replaced_with_at_sign/dev.txt'

# %% [markdown]
# > Get the line of the txt file

# %%
def read_lines(path):
  with open(path, 'r') as f:
    lines = f.readlines()
  return lines

# %%
train_lines = read_lines(train_dir)
val_lines = read_lines(val_dir)

# %%
type(train_lines)
# Out:
# list

# %%
train_lines[:20]
# Out:
# ['###24491034\n',
#  'BACKGROUND\tThe emergence of HIV as a chronic condition means that people living with HIV are required to take more responsibility for the self-management of their condition , including making physical , emotional and social adjustments .\n',
#  'BACKGROUND\tThis paper describes the design and evaluation of Positive Outlook , an online program aiming to enhance the self-management skills of gay men living with HIV .\n',
#  'METHODS\tThis study is designed as a randomised controlled trial in which men living with HIV in Australia will be assigned to either an intervention group or usual care control group .\n',
#  "METHODS\tThe intervention group will participate in the online group program ` Positive Outlook ' .\n",
#  'METHODS\tThe program is based on self-efficacy theory and uses a self-management approach to enhance skills , confidence and abilities to manage the psychosocial issues associated with HIV in daily life .\n',
#  'METHODS\tParticipants will access the program for a minimum of @ minutes per week over seven weeks .\n',
#  'METHODS\tPrimary outcomes are domain specific self-efficacy , HIV related quality of life , and outcomes of health education .\n',
#  'METHODS\tSecondary outcomes include : depression , anxiety and stress ; general health and quality of life ; adjustment to HIV ; and social support .\n',
#  'METHODS\tData collection will take place at baseline , completion of the intervention ( or eight weeks post randomisation ) and at @ week follow-up .\n',
#  'CONCLUSIONS\tResults of the Positive Outlook study will provide information regarding the effectiveness of online group programs improving health related outcomes for men living with HIV .\n',
#  'BACKGROUND\tACTRN@ .\n',
#  '\n',
#  '###20497432\n',
#  'BACKGROUND\tThe aim of this study was to evaluate the efficacy , safety and complications of orbital steroid injection versus oral steroid therapy in the management of thyroid-related ophthalmopathy .\n',
#  'METHODS\tA total of @ patients suffering from thyroid ophthalmopathy were included in this study .\n',
#  'METHODS\tPatients were randomized into two groups : group I included @ patients treated with oral prednisolone and group II included @ patients treated with peribulbar triamcinolone orbital injection .\n',
#  'METHODS\tOnly @ patients in both groups ( @ female and @ male ) completed the study .\n',
#  'RESULTS\tBoth groups showed improvement in symptoms and in clinical evidence of inflammation with improvement of eye movement and proptosis in most cases .\n',
#  'RESULTS\tMean exophthalmometry value before treatment was @ @ mm that decreased to @ @ mm in group I , compared with @ @ mm that decreased to @ @ mm in group II .\n']

# %%
def convert_lines_to_structured_data(lines):

  elements = lines [:]
  element_types = ['id' if str(x).startswith('##') else('break' if x == '\n' else 'item') for x in elements]

  id_list,order_list,text_list,label_list = [],[],[],[]

  for tp,el in zip(element_types,elements):  
    if tp == 'id':
      id = el
      row_num = 0
    elif tp == 'item':
      id_list.append(id)
      order_list.append(row_num)
      label_list.append(el.split('\t')[0])
      text_list.append(el.split('\t')[1])
      row_num = row_num+1
    else:
      pass
    
  return id_list,order_list,text_list,label_list

# %%
train_id, train_ord, train_sentences, train_labels = convert_lines_to_structured_data(train_lines)
val_id, val_ord, val_sentences, val_labels = convert_lines_to_structured_data(val_lines)

# %%
train_sentences[:3]
# Out:
# ['The emergence of HIV as a chronic condition means that people living with HIV are required to take more responsibility for the self-management of their condition , including making physical , emotional and social adjustments .\n',
#  'This paper describes the design and evaluation of Positive Outlook , an online program aiming to enhance the self-management skills of gay men living with HIV .\n',
#  'This study is designed as a randomised controlled trial in which men living with HIV in Australia will be assigned to either an intervention group or usual care control group .\n']

# %%
np.unique(train_labels)
# Out:
# array(['BACKGROUND', 'CONCLUSIONS', 'METHODS', 'OBJECTIVE', 'RESULTS'],
#       dtype='<U11')

# %%
len(train_sentences), len(val_sentences)
# Out:
# (2211861, 28932)

# %% [markdown]
# ### Lets select random 10% of the data for training
#
# - select only 10% of the data

# %%
ten_percent_len = int(len(train_sentences)*0.1)
len(train_sentences),ten_percent_len
# Out:
# (2211861, 221186)

# %%
train_df = pd.DataFrame({'id':train_id, 
                         'order':train_ord, 
                         'sentence':train_sentences,
                         'label':train_labels})

# %%
train_df_10_percent = train_df.sample(ten_percent_len, random_state =42)
len(train_df_10_percent)
# Out:
# 221186

# %%
train_id = train_df_10_percent['id'].tolist()
train_ord = train_df_10_percent['order'].tolist()
train_sentences = train_df_10_percent['sentence'].tolist()
train_labels = train_df_10_percent['label'].tolist()

# %% [markdown]
# ### Encoding of the Text Labels

# %% [markdown]
# > One Hot Encoding of the labels

# %% [markdown]
# > convert the list into a numpy array and expand its dimention so that it can feed int the onehot encoder

# %%
train_labels = np.expand_dims(np.array(train_labels), axis = 1)

# %%
val_labels = np.expand_dims(np.array(val_labels), axis = 1)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
onehot = OneHotEncoder(sparse_output = False)

# %%
onehot.fit(np.array(train_labels))
# Out:
# OneHotEncoder(sparse_output=False)

# %%
train_label_onehot = onehot.transform(train_labels)
val_label_onehot = onehot.transform(val_labels)

# %% [markdown]
# > Lets label encode the labels as well for the comparison of the results

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
label_encoder.fit(train_labels)
# Out:
# LabelEncoder()

# %%
train_label_label_encoded = label_encoder.transform(train_labels)
val_label_label_encoded = label_encoder.transform(val_labels)

# %% [markdown]
# ### Standardization of Sentences

# %% [markdown]
# > lets define the text standardistion function

# %%
import string
import tensorflow as tf

def text_standardization(text, to_lower=True, rm_punctuations=True, rm_html=True, rm_newline=True):

  """
  Objective
  ---------
  Function that takes the raw text process and return the standardized text for natural language processing task

  Note : It is fuction need to map into each elements of an iterative object

  example --> train_sentences = [text_standardization(x) for x in train_sentences]

  Parameters
  ---------
  text : text to standardize
  to_lower : lower all the alphabets in the text
  rm_punctuations : bool -- > remove the punctuations
  rm_html : bool -- > remove the thml tages from the text
  rm_newline : bool -- > remove the newline ('\n')

  """
  
  if to_lower:
    x = tf.strings.lower(text)  # convert all the text into lowercase
  if rm_html:
    x = tf.strings.regex_replace(x, '<[^>]*>', '')  # replace the html tags with nothing
  if rm_punctuations:
    x = tf.strings.regex_replace(x, '[' + string.punctuation + ']', '')  # replace the punctuations with nothing
  if rm_newline:
    x = tf.strings.regex_replace(x, '\n', '')  # remove the new line characters
  x = x.numpy().decode('utf-8')  # convert into a numpy value and decode the text into utf-8 format
    
  return x

# %% [markdown]
# lets standardise the text

# %%
train_sentences = [text_standardization(x) for x in train_sentences]
train_sentences[:3]
# Out:
# ['because most infant deaths occur in the first few month of life  maternal supplementation may improve infant survival ',
#  'the objective of this study was to determine the efficacy and safety of nebulized   hypertonic saline solution and salbutamol in the treatment of mild to moderate bronchiolitis ',
#  'this randomized  doubleblind  multicenter study was conducted to confirm a previous finding that lansoprazole relieves heartburn faster than omeprazole in patients with erosive esophagitis ']

# %%
val_sentences = [text_standardization(x) for x in val_sentences]
val_sentences[:3]
# Out:
# ['adrenergic activation is thought to be an important determinant of outcome in subjects with chronic heart failure  chf   but baseline or serial changes in adrenergic activity have not been previously investigated in a large patient sample treated with a powerful antiadrenergic agent ',
#  'systemic venous norepinephrine was measured at baseline   months  and  months in the betablocker evaluation of survival trial  best   which compared placebo treatment with the betablockersympatholytic agent bucindolol ',
#  'baseline norepinephrine level was associated with a progressive increase in rates of death or death plus chf hospitalization that was independent of treatment group ']

# %% [markdown]
# ### Define the goabal varibales

# %%
len_list = [len(x) for x in train_sentences]
np.percentile(len_list,95)
# Out:
# 268.0

# %%
bs = 32
vocab_size = 10000
pad_len = 248
oov_token = '<OOV>'

pad_style = 'post'
trunc_style = 'post'

embed_len = 16

# %% [markdown]
# ### Tokenize the text & Pad the sentences

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token = oov_token)

# %%
tokenizer.fit_on_texts(train_sentences)

# %%
train_sentences
# Out:
# ['because most infant deaths occur in the first few month of life  maternal supplementation may improve infant survival ',
#  'the objective of this study was to determine the efficacy and safety of nebulized   hypertonic saline solution and salbutamol in the treatment of mild to moderate bronchiolitis ',
#  'this randomized  doubleblind  multicenter study was conducted to confirm a previous finding that lansoprazole relieves heartburn faster than omeprazole in patients with erosive esophagitis ',
#  'twentyone patients       had respiratory depression  hypercarbia  etco   mm hg  or hypoxia  oxygen saturation    for over  minute     patients       had hypercarbia  and  patients     had both hypoxia and hypercarbia ',
#  'plasma urea and creatinine concentrations were determined at induction of anesthesia and  or  h postoperatively ',
#  'healthy male volunteers  n    age  years  randomly received a single sublingual dose of asenapine  mg after  h fasting  treatment a  reference   after a highfat meal  treatment b  and after  h fasting with a highfat meal at  h postdose  treatment c  ',
#  'however  the clinical competency of newly qualified nurses continues to stimulate debate about the adequacy of current methods of clinical skills education and emphasises the need for innovative teaching strategies ',
#  'agreement was good with some relevant exceptions ',
#  'a large interindividual variation was observed ',
#  'tenderness after doses two and three occurred in    and   of triple antigen subjects  compared to    p      cl diff       and    p      cl diff       of ndtpw subjects ',
#  'injections were given under imaging control ',
#  'eighteen children with congenital heart disease were prospectively randomized into a control group  n    and a group who underwent uf  n    ',
#  'the dietary intervention had no effect on gastrointestinal side effects or other aspects of hrqol ',
#  'flubiprofen hydroxylation in vitro was reduced to        of control by    volvol  brewed tea  to        of control by grape juice  to        of control by cranberry juice  to        of control by cranberry juice placebo  and to        of control by the index inhibitor sulfaphenazole   micromoll   p   for all comparisons versus control  ',
#  'motivationalenhancing factors  pain intensity  physical functions  and exercise compliance ',
#  'the efficacy and safety of cetirizine  mg qd  terfenadine  mg bid  and placebo were compared in patients with seasonal allergic rhinitis ',
#  'we evaluated the results of schirmer test  fluorescein and rose bengal staining scores  tear film breakup time  but   and subjective symptom scores before and  weeks after treatment ',
#  'maximum period of observation was  weeks ',
#  'these findings show that glycerol is an effective osmotic agent that can replace glucose in short dwells and show no acute mesothelial damage ',
#  'aes were generally mild and not related to either the drug or the dose ',
#  ' healthy crossbred dogs weighing      kg ',
#  'in this trial  we compared child protective services  cps  recidivism outcomes between the homebased safecare  sc  model for child neglect and comparable homebased services  but without sc modules  for parents in the cps system across  quality control strategies  coached  c  and uncoached implementation ',
#  'many patients continue to take regular beta agonists  often at high doses  contrary to national and international guidelines ',
#  'tapering of clopidogrel over a certain period of time before stopping the drug completely might provide a way to attenuate this supposed phenomenon ',
#  'twelve asthmatic patients of mean age  years  with a forced expiratory volume in one second  fev    predicted and forced expiratory flow    fef    predicted  on less than or equal to  microgramsday inhaled corticosteroid  were studied in a double blind placebo controlled crossover design comparing single doses of inhaled budesonide        micrograms and fluticasone propionate        micrograms ',
#  'we sought to determine whether avc is associated with the presence and extent of overall plaque burden  as well as to plaque composition  calcified  mixed  and noncalcified  ',
#  'the number of adverse events was similar in the moxonidine and placebo groups ',
#  'the percentage of patients reaching relative functional independence on the barthel index  score      at  days was   in the clomethiazole group and   in the placebo group ',
#  'the treatments were oxytetracycline spray to all sheep  positive control  and one or more of parenteral administration of longacting oxytetracycline  flunixine meglumine  and foot trimming on day  or  of diagnosis ',
#  'fisoprostane in urine increased in the placebo group after  months  but there was no clear difference in treatment effect between supplemented and nonsupplemented patients on the urinary levels of fisoprostanes and ketodihydropgf ',
#  'this prospective  randomized  placebocontrolled study was performed with parallel groups ',
#  'the increases were significantly different  p    matched pairs ttest  twotailed  suggesting a greater increase in corneal staining for the povidone lubricant ',
#  'kg ',
#  'the lefthand grip strength was significantly increased at week  ',
#  'thirty p episodes occurred during followup   in g patients and  in i patients   per  months and  per  months  respectively  ',
#  'data collected through questionnaire after intervention were compared with the baseline data through analysis of covariance and chi    test ',
#  'at  hours after extubation  increasing obesity was associated with decreasing fev    and mef in patients anesthetized with propofol but not desflurane  p    ',
#  'the difference  however  was not statistically significant ',
#  'eightynine percent of the ttm group and   of the control group were present at year and  and    respectively  were present at year followup ',
#  'at twoyear followup  all patients continued to improve  with those in the combined approach improving more than those in the medicationalone group ',
#  'a prospective  doublemasked trial was conducted in healthy term formulafed infants  n    randomized between  and  days of age to study formulas containing   unfortified       and  mcgl of lutein ',
#  'children in the nonio group visited the clinic for an extra checkup at  weeks as well as before and after lip repair and soft palate closure ',
#  'during the baseline phase  patients prophylactically treated their first pmp after the screening visit with singleblind placebo ',
#  'after the treatment  the umannwhitney test demonstrated that the fes group produced a significantly higher increase of the muscular force produced by both the quadriceps during mvc with respect to the control group  p    ',
#  'altogether   and  patients received  mg and  mg twicedaily oseltamivir  respectively  their enrollment characteristics  mean age    vs   years  and illness severity were comparable ',
#  'wholebody hypothermia was achieved using the hyperthermiahypothermia cooling system with servo control of esophageal temperature to  degrees c for  hours followed by slow rewarming ',
#  'eligible patients were randomized to receive three drops of either ciprofloxacin    dexamethasone   or ciprofloxacin   into the affected ear or ears twice daily for  days ',
#  'the present study investigated predictors of treatment completion during a standardized exposurebased psychotherapy for ptsd ',
#  'the addition of alprazolam was most effective for symptoms of excitement and uncooperativeness  particularly in the initial hours of treatment ',
#  'although the percentage of gcsf  patients commencing the following course on day  was significantly higher    v   after the first and   v   after the second course  p     the median delay between the two courses was only  day less in gcsf  patients  median delay after first copad  m    v  days  p    after second   v  days  p  not significant  ',
#  'both treatment courses were  months ',
#  'this may have been due in part to a longer median survival time of  months for patients in arm a  compared with an anticipated survival of  months ',
#  'recoverin levels were fold higher in patients with recurrent gbm relative to controls ',
#  'dpp participants  n    in three treatment arms  intensive lifestyle  metformin  and placebo  completed the beck depression inventory  bdi  and reported on use of antidepressant medicines at randomization and subsequently at each annual visit  average duration in study  years  ',
#  'knowledge gained from the rct will be useful to health care professionals  policy planners and arthritis stakeholders ',
#  'our results clearly show that induced expectations of increased mechanical pain sensitivity after hfs facilitates the reported pain intensity after hfs more than when no information is given ',
#  'to evaluate the efficacy and safety of tadalafil in men with treatmentemergent sexual dysfunction due to serotonin reuptake inhibitors ',
#  'this article provides an overview of the study including the multicomponent intervention and participant demographics ',
#  'two placebocontrolled parallelgroup studies were conducted in healthy male volunteers ',
#  'the duration of mechanical ventilation  the mortality rates in the intensive care unit  at hospital discharge  and at      and  days and  year after randomization  and adverse events were recorded ',
#  'the mean reduction in episodes of urgency urinary incontinence per day over the course of  months  from a baseline average of  per day  was  in the anticholinergic group and  in the onabotulinumtoxina group  p    ',
#  'couples then were managed by assisted reproduction with randomized allocation of oocytes for fertilization with a standard sperm preparation or with added sperm stimulants  either  mm pentoxifylline alone or combined with  mm deoxyadenosine ',
#  'pulse wave velocity  pwv  is a direct measure of arterial stiffness ',
#  'patients were enrolled into a prospective randomized study of sensing of vf and r waves in normal rhythm ',
#  'after treatment discontinuation milnacipran was associated with less emergent symptoms ',
#  'among the osteoarthritisaffected joints  acs treatment significantly decreased synovial membrane hyperplasia  compared with placebotreated joints  although not significant  the acstreated joints also appeared to have less gross cartilage fibrillation and synovial membrane hemorrhage ',
#  'the gross motor function measure  gmfm  was used to test motor skill development ',
#  'the aim of this study was to assess the haemodynamic responses  adverse events and recovery characteristics associated with sevoflurane and ketaminemidazolam anaesthesia for paediatric extracorporeal shockwave lithotripsy ',
#  'to describe the clinical and laboratorial profile of hellp syndrome patients admitted at an obstetric intensive care unit  icu  and included in a randomized clinical trial to evaluate the efficacy of dexamethasone in this clinical setting ',
#  'patients with pad who needed to undergo imaging workup and who had an anklebrachial pressure index  abpi  of less than  were recruited by vascular surgeons between january  and september  ',
#  'changes in bun and serum creatinine from baseline were not significantly different in the two treatment groups ',
#  'other migraine headache characteristics  such as nausea  photophobia  phonophobia  and functional disability  were significantly improved  to  hours after treatment with the acetaminophen  aspirin  and caffeine combination compared with placebo  p  or    ',
#  'three patients in the control group developed four infections ',
#  'at  weeks  continence was even better in the fixation group       vs       p    ',
#  'the tibial nerve block and sciatic nerve block were performed  cm    ci   to   and  cm    ci   to   proximal to the popliteal crease  respectively    ci for difference between means   to   p    ',
#  'sixteen postmenopausal type  diabetics treated with diet or oral hypoglycaemic therapy completed a randomized doubleblind crossover trial of dietary supplementation with isoflavones from red clover  approximately  mgday  for  weeks compared to placebo ',
#  'to assess the long term effectiveness of the  green prescription  programme  a clinician based initiative in general practice that provides counselling on physical activity ',
#  'participants received either  iud of alpha tocopherol  n      mgd of memantine  n     the combination  n     or placebo  n    ',
#  'methotrexate  mtx  is a cornerstone in the treatment of rheumatoid arthritis ',
#  'the secondary outcome of interest was the effect on plasmodium vivax prevalence detected in the same way ',
#  'experienced raters who were blinded to control versus experimental status of the subjects scored the magnetic resonance imaging  discogram  psychometric tests  and discography videotapes of the subjects  pain behavior ',
#  'one group  io     wore passive maxillary plates during the first year  the other group  io     did not ',
#  'six subjects went through the isoproterenol and epinephrine infusions while taking placebo and five other subjects while taking entacapone ',
#  'in the subsequent randomized phase ii part  the rd will be evaluated in the experimental arm  compared to the standard arm  fsrt with a total dose of  gy in single doses of  gyprimary endpoint of the phase i part is toxicity ',
#  'this study assesses the efficacy  toxicity and pharmacokinetic profile of trabectedin with or without prophylactic dexamethasone cotreatment in patients with recurrent advanced soft tissue sarcoma  sts  ',
#  'university hospital ',
#  'poor communication has also been cited as a possible barrier to recruitment ',
#  'qol in the combined treated group was improved after treatment with the improvement of scores in all domains  including functional and symptom subdomain  while it in the control group deprived significantly  showing significant difference between the two groups  p    ',
#  'demographics  age and gender   fracture classification and injury severity score were comparable in the two groups  p    ',
#  'among  subjects were interviewed  the overall prevalence of smokers was    n     mean age   years  sd   years  ',
#  'as endocardial visualization and confidence of interpretation decreased in unenhanced studies  a greater impact of the use of a contrast agent on dse accuracy was observed  p    ',
#  'both regimens produced comparable efficacy  with less hematologic and greater gastrointestinal toxicity with ip ',
#  'when patients experience side effects with one  the st  atd  it is usually discontinued and another is administered  the nd atd  ',
#  'the radiologists spent more time viewing cases that had significant findings or cases for which they had less confidence in their interpretation ',
#  'the primary endpoints were the first occurrence of a hf event or death and the separate occurrence of allcause mortality as in maditcrt ',
#  'in patients with newly detected hypertension  baseline echocardiography detects more patients with hypertensive target organ damage  but does not lead to a reduction in left ventricular mass index or improved bp control after  months of therapy ',
#  'maintenance of therapeutic gains was demonstrated at a month followup assessment ',
#  'the japan clinical oncology group conducted a phase iii trial for a year period starting from october  to determine whether intraoperative intrapleural hypotonic cisplatin treatment could effectively control pleural disease and thereby prolong the survival of these patients ',
#  'endoscopic biliary sphincterotomy  ebs  results in permanent loss of sphincter function and its longterm complications are unknown ',
#  'until this is available  the minisling should be used with caution ',
#  'we conducted a prospective  randomized  doubleblind  placebocontrolled  clinical trial in a tertiary pediatric ed between september  and january  ',
#  'these results highlight the point that when basal  am plasma cortisol levels are suppressed  a comparable degree of dynamic impairment of hpa axis response is also likely to be found with physiologic testing ',
#  'the infectious complication rate in the fasttrack group    is lower than the other group    p    ',
#  'the secondary efficacy endpoints were differences in daily mean   i  voiding frequency at  and weeks   ii  urgency frequency   iii  urgency incontinence frequency   iv  incontinence frequency   v  nocturia frequency  and  vi  quality of life score ',
#  'ten patients   eyes  were treated with mdf and ten   eyes  served as controls ',
#  'mb is safe for the treatment of uncomplicated falciparum malaria  even in gpd deficient african children ',
#  'acute rejection episodes were confirmed histologically and treated with intravenous methylprednisolone  or antithymocyte globulin if steroid resistant ',
#  'human genomes harbor copy number variants  cnvs   which are regions of dna gains or losses ',
#  'hypoxemia during the induction of general anesthesia for the morbidly obese patient is a major concern of anesthesiologists ',
#  'compared with a noninvasive approach  an invasive approach resulted in reduced day and month mortality rates in patients with significant lvd    versus    adjusted odds ratio  or      confidence interval  ci   to   and   versus    or     ci  to   respectively ',
#  'plasma and rbc folate values at wk postpartum correctly identified the quartile of folate intake of only  of      and  of      of subjects  respectively ',
#  'pregnancy rates in each of the study protocols were generally higher than in the normal treatment group ',
#  'all lesions were categorized for size and location within the colonrectum ',
#  'adverse effects were similar between both groups ',
#  'theoretically  cq should be dosed according to body surface area  bsa  ',
#  'in all   patients were randomly assigned by  institutions over a period of  years ',
#  'subjects with atopic syndrome often perceive symptoms from various organs ',
#  'our technique can not replace eb by hsc ',
#  'subgroup analysis for patients with acute coronary syndrome  acs  showed that deltampar induced by  micromoll adp          vs          p     deltampar induced by  micromoll          vs          p     deltacdp          vs          p    and deltapac          vs          p    in triple group were significantly higher than that in dual group ',
#  'to compare the efficacy of an alcoholbased hand sanitizer to standard hand washing in reducing illness and subsequent absenteeism in schoolage children ',
#  'however  subjects with peanut allergy often report severe reactions after minimal contact with peanuts  even through intact skin ',
#  'prospective randomized clinical outcome study ',
#  'as hypothesized  the effect of collaborative care on si was mediated by the treatment s effect on depression ',
#  'the percentage changes from  to  h   h valueh value   baseline   in motilin    vs    p    and orexina    vs    p    concentrations were significantly higher in the lgi group than in the hgi group ',
#  'however  lack of ongoing followup after discharge makes evaluation and disease management difficult ',
#  'the main cause of the dlt displacement during lateral positioning appears to be related to movement of the head and neck ',
#  'the main outcome was persistent postthoracotomy pain at  months ',
#  'the abnormalities were correctly classified as either benign or malignant in   of cases by both observers on the chest radiographs and in   and   of cases on the ct scans by the first observer and the second observer  respectively ',
#  'we conducted a clinical trial in  patients with the ms   controls and  patients receiving  gday of pufas  ',
#  'vas pain scores were evaluated before  in the middle of  and after treatment ',
#  'sixty eyes of  patients with refractory glaucoma were randomized to receive intraoperative mmc   mgml for  minutes   n    or balanced salt solution  n    during ahmed glaucoma valve implantation ',
#  'clinical outcomes and acute and late toxicities were determined and compared ',
#  'the pd comm pilot is a three arm  assessorblinded  randomized controlled trial ',
#  'the students then diagnosed eight new patients with similar characteristics interspersed with the original eight patients ',
#  'anaesthesia was maintained by midazolam  mgkgmin  alfentanil  mgkgmin and oxygen enriched air and muscle relaxation with atracurium  mgkgmin ',
#  'thirtythree percent of abcd children    who had visited the dentist had   appointment compared to  percent    for the children not in abcd who had visited the dentist ',
#  'none ',
#  'no statistically significant differences between the groups were found in ulcerrelated symptoms or in ulcer healing ',
#  'all patients in groups a and b had fever of different degrees  which resolved spontaneously in  h',
#  'sixteen     pta group patients versus eight     cba group patients were asymptomatic at followup  p    ',
#  'the need for extra visits was significantly lower in the active group    vs    ',
#  '   the mitochondrial membrane bound pla    activity  plasmal and mitochondrial mda content were significantly increased and succinate dehydrogenase  sdh  activity of mitochondria decreased markedly in endotoxic shock rats  p    ',
#  'furthermore  psychiatric symptom profile is not predictive of the degree to which cognitive symptoms respond to cognitive remediation ',
#  'mean anesthesia duration was shorter  p    for laparoscopic abdominoperineal resection when compared to conventional approach   and  minutes  respectively ',
#  'supervised homebased rt with highquality equipment was effective for improving strength  along with other secondary outcomes in obese patients with type  diabetes ',
#  'in this week phase  trial  we randomly assigned overweight or obese adults  aged  years   with a bodymass index of  kgm    and two or more comorbidities  hypertension  dyslipidaemia  diabetes or prediabetes  or abdominal obesity  to placebo  oncedaily phentermine  mg plus topiramate  mg  or oncedaily phentermine  mg plus topiramate  mg in a  ratio in  centres in the usa ',
#  'mean knowledge scores were higher in the video group     compared to routine discussion        confidence interval  ci  for the difference   to    ',
#  'the median total intubation time  including the administration of local anaesthesia  was  vs s in the ascope and olympus groups  respectively  p    ',
#  'the patients  clincheck  align technology  santa clara  calif  was planned so that the movements to be investigated were performed in isolation in the respective quadrant ',
#  'extensive hemodynamic monitoring was performed  and  minutes after the end of infusion ',
#  'the latter was designed to elicit preferences based on patient tradeoffs for route of administration  benefits  and side effects of commonly used treatment options for knee pain ',
#  'study duration was  days  with a last control on day   ',
#  'the present placebocontrolled study was carried out to evaluate the analgesic effect of highvolume infiltration analgesia in bilateral total knee arthroplasty  along with a detailed description of the infiltration technique ',
#  'logistic regression analysis was performed to identify distal findings associated with apn ',
#  'our primary outcome  tti  was defined as the time from insertion of the laryngoscope blade until first breath ',
#  'similar weight and diet changes occurring in patients with normal plasma cholesterol were either increased or without affect ',
#  'twentyfour adult asa  patients premedicated with  mgkg of midazolam were instructed to take vital capacity breaths of  minimum alveolar concentration  mac  of either xenon or sevoflurane until they lost consciousness ',
#  'in infants with only rotavirus infection  total cumulative stool output was  gkg body weight among those given placebo  n    and  gkg body weight among those given arp  n     a difference of  gkg body weight or      confidence interval    gkg body weight  p    ',
#  'omega supplement lowered bdi score significantly after  months of intervention ',
#  'a randomized multicenter study was conducted to investigate the efficacy of total androgen blockade  tab  for patients with previously untreated prostate cancer using the steroidal antiandrogen chlormadinone acetate  cma  and the nonsteroidal antiandrogen flutamide ',
#  'quartiles of baseline hba  c  values were    q      q      q  and    q   and the incidence rates of diabetes by quartiles were                  and      cases personyears  respectively ',
#  'after bonding  the sbs of the brackets were tested with a universal testing machine ',
#  'in addition  the thickness of the interventricular septum  p     the left ventricular mass  p     and the mass index  p    had decreased significantly after  weeks in the patients who exercised  whereas there was no significant change in the nonexercisers ',
#  'no significant evidence supported that needling caused capillary contraction  but the capillary vasomotor amplitude at hegu  li   increased remarkably ',
#  'a significant proportion will report recurrence or continual pain and health care consumption ',
#  'treatmentemergent day serious adverse event rate defined as a composite of death  myocardial infarction  stroke  hospitalization for worsening heart failure  perforation  tamponade  or sustained ventricular arrhythmias ',
#  'time to meet discharge criteria was  median  iqr     ci   mp vs placebo            vs          h  the mean difference    ci  being    to   h  p   ',
#  'one hundred twentyone edentulous patients were treated with an iro   endosseous implants  n    or a conventional cd  n    ',
#  'all horses defaecated and urinated normally  and no excitement  sedation or ataxia were observed after meth administration ',
#  'quality of life was assessed by using the european organisation for research and treatment of cancer instrument ',
#  'to observe the effects of the acupuncture on the gastric motivity in patients with functional dyspepsia  fd  ',
#  'to address the frequency of side effects of ritalin therapy in children with attention deficit hyperactivity disorder  adhd  using the barkeley side effects questionnaire  bseq  in a clinical setting ',
#  'by means of randomization these patients were distributed into  groups  patients of group   n    after washout period following withdrawal of previously taken bblockers received acridilol for  weeks together with other antihypertensive therapy ',
#  'families with psychologic symptoms were more likely to report that access to a counselor  ptsd  p    depression  p    and information about spiritual services might have been helpful while the patient was in the icu  ptsd  p    depression  p    ',
#  'flush tears were collected from  healthy neophytes before lens wear  during the first day of lens wear  and after  month adaptation ',
#  'lowdose tac accompanied by prednisone is enough to induce remission in the majority of patients with imn ',
#  'infants of mothers in both groups showed normal growth and survival ',
#  'cpm was induced by placing the subjects  contralateral arm in a hot water bath   c  for min ',
#  'it has been proved in animal models that postconditioning  pc  could attenuate reperfusion injury ',
#  'incidences of primary and secondary outcomes will be compared between groups ',
#  'the study was approved by the institutional ethics committee  and all patients gave written informed consent ',
#  'owing to high injury rates  safety interventions are needed in the construction industry ',
#  'a doubleblind  parallelgroup  randomized controlled trial was conducted among healthy men and women aged  years  n    ',
#  'in  of  healthy controls  a cool hypoesthesia area developed in the groin after the lidocaine block ',
#  'more women who had multiple antenatal contraceptive counselling sessions used modern contraceptive methods than those who had a single postnatal counselling session    vs    p    ',
#  'we tested the effects of rosuvastatin combined with ramipril on atheroma volume and its mechanism in de novo  intermediate coronary artery disease ',
#  'both early    days  occurrences of sustained vt and vf were associated with a higher risk of later mortality  p    ',
#  'at the baseline there was not any significant difference between the control and intervention groups in terms of irrational prescribing habits ',
#  'few trials have been conducted regarding the potential benefits of oral procyanidin in melasma ',
#  'patients who switched to peginterferon alfaa achieved higher week  hbeag seroconversion rates vs those who continued etv    vs    p    ',
#  'also  lamb patients     versus  patients     on placebo had no significant decline during the entire treatment  p    ',
#  'using the cpb and npb in a random crossover design  participants delivered  ventilations to test lungs connected to gas flow analysers for the randomly assigned target tv ranges ',
#  'according to the patients  global evaluation    of patients in thiocolchicoside group evaluated the treatment as very goodgood  p    ',
#  'after oe     antithrombin iii decreased from   to    p     the metalloproteinase  tissue inhibitor of metalloproteinase ratio increased  p     and eselectin decreased from      to      ngml  p    ',
#  'subjects could alter the amount  but not the composition of foods eaten ',
#  'elderly patients subjected to general anaesthesia displayed more frequent cognitive impairment during the immediate postoperative period in comparison to those who received a regional technique ',
#  'the wounds were measured by digital photography and imagej software ',
#  'this randomized trial on infant feeding turned out to be feasible  and dietary compliance was acceptable ',
#  'ea can lower the severity of urinary incontinence and improve clinical symptoms of micturition in stroke patients ',
#  'sixty inpatients of icp were randomly divided into two groups  the group a treated with ychd and the group b treated with sam ',
#  'we failed to find a statistically significant difference between the two groups in the number of antidepressant responders     decline in hrsd or hrsd     active and  sham  or the mean hrsd change from baseline over the  weeks  t    p    ',
#  'in study  inhaled   saline with indomethacin  osmolarity  mosmkg  increased the mbs pd by  doubling doses    ci  to   compared with only     ci  to   and     ci  to   doubling doses with   saline   mosmkg  and   saline   mosm  kg   respectively ',
#  'statistical methods followed established methods for crossover designs  including student t tests to compare average intrapatient differences between treatments and linear models to adjust for potential concomitant covariates ',
#  'they were randomized to receive treatment for these disorders in the primary care clinic or to a brokerage case management model that linked patients to communitybased services ',
#  'fibrin ddimer antigen did not vary significantly in any group ',
#  'maximum trial dose of armodafinil was  mgd ',
#  'causes of death were mainly related to extreme prematurity and were similar in the two groups ',
#  'total oxycodone consumption was also similar  mg     and  mg      p     respectively ',
#  'they were given an appointment time ',
#  'the effects of damphetamine on     c  flb  bp  nd  and distribution volume  v  t   in the frontal cortex were not different from those of placebo ',
#  'of  teens eligible for the rct   enrolled early  and  enrolled late  leaving  nonparticipants ',
#  'this study compares the anesthetic potency  duration  and side effects of subarachnoid meperidine and lidocaine for postpartum tubal ligation ',
#  'at baseline healthy subjects had higher urinary levels of total cortisol metabolites  tcm  than subjects with asthma ',
#  'they completed the interpersonal support evaluation list and the yale social support index and provided saliva samples for assessment of diurnal cortisol levels on each of  consecutive days ',
#  'there was no significant change in bp reduction between the first and second hour periods of abpm with valsartan     mm hg   whereas enalapril was associated with a significant increase in bp over this period     mm hg  p   vs first  hours  p   vs valsartan  ',
#  'hydroxyethyl starches  hes     voluven  and    venofundin  impair coagulation less than older hes solutions with higher molecular weight and molar substitution ',
#  'final baselineadjusted plasma homocysteine concentrations were significantly lower and b vitamin concentrations were significantly higher in the treatment group than in the placebo group  p    ',
#  'after treatment  expressions of eralpha and progesterone receptors were upregulated in both glands and stroma by both treatments  but to a lesser extent in glands by combined treatment ',
#  'in   of bdptreated patients colonoscopy showed remission compared with   of asa  p    ',
#  'home discharge time was faster in the  mg group   min  and in the  mg group   min  than in the  mg group   min  p    ',
#  'we evaluated the effect of cervical spine immobilization techniques on orotracheal intubation performance with a highfidelity infant simulator ',
#  'a randomized  controlled  repeated measures research design was used ',
#  'angle of deviation was recorded preoperatively and at  week   months  and  months  any postoperative complications and side effects were noted ',
#  'there was no significant reduction in symptom intensity score between baseline and at the end of the study in the waitlist group   vs   p  ns  ',
#  'the total prostanoid levels increased after hepatectomy  p    ',
#  'a random sample of  persons was drawn from the total population of the city of kuopio  eastern finland  aged  years on january     n    ',
#  'the purpose of this study was to describe the rationale and design of a randomized controlled trial analyzing the effects of mesh type  ultrapro versus prolene mesh  on postoperative pain and wellbeing following an endoscopic totally extraperitoneal  tep  repair for inguinal hernias  short  tulp trial  ',
#  'the chemotherapy was repeated every  weeks as a cycle ',
#  'there were no effects of the intervention on any other outcome ',
#  'in the multivariate analysis with overall survival as the end point  the female sex was an independent favorable prognostic factor ',
#  'compared with the ncep diet  the mlc diet  which is lower in total carbohydrates but higher in complex carbohydrates  protein  and monounsaturated fat  caused significantly greater weight loss over  weeks ',
#  'fortythree patients met the criteria for highrisk cancer after rrp  gleason score  or    ptc or gleason score  concomitant with ptab and positive surgical margins  and were prospectively randomized to either observation or ad for  months ',
#  'the year eventfree and overall survival probabilities for all  patients were      confidence interval  ci    to   and      ci   to    respectively ',
#  'in vitro fertilization and icsi ',
#  'because of the easy solubility of this medication through the skin  a cream applied to the area of hair growth would be expected to decrease hirsutism locally ',
#  'this could  at least theoretically  offer the advantage also to remove uraemic toxins in the molecular weight range of albumin or of albuminbound toxins ',
#  'the primary objective of this study was to explore whether patients report more cognitive failures  year after cabg than preoperatively ',
#  'to determine whether there are differences in patient preference and extent of laryngeal visualization between video rigid   degree endoscope  laryngoscopy  vrl  and laryngeal mirror examination  lme  ',
#  'paired sample student s ttests were used to detect differences between the baseline and  month after treatment initiation in mean ocular symptoms  fluorescein breakup time  fbut  values  and schirmer scores in each group ',
#  'at mean followup of   group   and   group   months   and  men had successful outcomes ',
#  'at the end of therapy it was possible to match the beneficial effects of eye drops with carnitin  taurine  sodium hyaluronate and eledoisin ',
#  'doubleblind randomized trial with placebo control ',
#  'cobedding of preterm twin infants provides tactile  olfactory  and auditory stimulation and may affect pain reactivity ',
#  'both standard and immuneenhancing oral formulas are widely used to forestall hiv wasting and to promote immune function ',
#  'abortion failure and ibuprofen side effects in the two groups were similar ',
#  'at  months  childturcotte pugh scores were reduced by   in the gdp group and   in the control group  from baseline  p     model for end stage liver disease scores were reduced by   and    respectively  p    ',
#  'followup was  month ',
#  'prodigeffcdadci is a prospective multicentre controlled randomised phase iiiii trial comparing current standard of care of perioperative chemotherapy  x cycles of epirubicin  cisplatin  fluorouracil  with a strategy of primary surgery followed by adjuvant chemotherapy   cycles of epirubicin  cisplatin  fluorouracil  in patients with a stage ibiii gastric signet ring cell tumour ',
#  'sensitivity analysis estimated interrater agreement and screening accuracy ',
#  'there was no study withdrawals associated with technology ',
#  'australian new zealand clinical trials registry  wwwanzctrorgau  identifier  actrn ',
#  'the total effective rate was   in the treatment group and   in the control group with a significant difference between the two groups  p     the longterm therapeutic effect in the treatment group was better than that in the control group ',
#  'retrospective analyses showed that the improvement in the symptoms of adhd was greater in patients treated with ldx than orosmph ',
#  'ggr is a modestly effective nonhormone therapy option for the treatment of moderatetosevere hot flashes due to menopause and is well tolerated with titration ',
#  'in patients older than  years with moderate or severe chronic knee pain  neither laser nor needle acupuncture conferred benefit over sham for pain or function ',
#  'meanwhile  this study determined the incidence of acute pain as well  which may lead to bias to the results of acute pain ',
#  'currently very few options are available for the treatment of tbm and the mortality rate remains unacceptably high with severe disabilities seen in many of the survivors ',
#  'etoricoxib and naproxen were generally well tolerated ',
#  'median pedt scores of paroxetine  acupuncture  and placebo groups were     and  before treatment  and     and  after treatment  respectively  p    p    and p    respectively  ',
#  'delayed cerebral ischemia  dci  and early clinical outcome of patients were determined ',
#  'gaus out performed cmds in the identification of subjects with both mild and severe ui ',
#  'treatments started on separation from cpb and concluded at the end of the intraoperative experience ',
#  'in group   partners participated in  of the  visits ',
#  'we conducted a phase ii randomized study to assess the efficacy  with response as the primary endpoint  and the toxicity of gemcitabinecisplatin  gp  and gemcitabinecarboplatin  gc  in patients with advanced nonsmall cell lung cancer  nsclc  ',
#  'therefore this comparison suggests that transient cart in acute infection might result in a modest increase in the probability of low vl subsequently ',
#  'to describe the costs of providing support to breastfeeding lowincome women and compares costs to cost offsets of the intervention ',
#  'however  the efficacy of prophylactic hc to prevent the use of vasopressors for a defined hypotensive state has not been studied ',
#  'to compare the effects of mifepristone of different doses on emergency contraception ',
#  'the abdominal fat mass was assessed by computed tomographic scans ',
#  'although antihcv antibody positive patients in the intervention group were more likely to have been referred to a hepatology clinic  this was not statistically significant  p    ',
#  'hinged ankle braces supposedly allow almost free dorsiflexion and plantar flexion of the foot in the sagittal plane ',
#  'significant improvements were seen with ferric carboxymaltose in the distance on the minute walk test and qualityoflife assessments ',
#  'no differences in cardiac remodelling were detected by echocardiography  with the exception that hearttype fatty acid binding protein at      months was lower in the thrombectomy group  p    ',
#  'both the ao and bi groups had reductions in antepartum alcohol consumption  but differences in reductions by group were not statistically significant  p    ',
#  'both total movement and strain were significantly reduced in entrapped lung ',
#  'a multicenter pilot study enrolled women with postdate pregnancies with bishop score  or   who were undergoing antepartum fetal heart rate testing ',
#  'patients allocated to physiodirect had a shorter wait for treatment than those allocated to usual care  median  days vs  days  armtime ratio     confidence interval  ci   to   and had fewer nonattended facetoface appointments  incidence rate ratio     ci  to    ',
#  'pain scores decreased with each consecutive injection ',
#  'new adult patients were prospectively randomized to care by family physicians and general internists ',
#  'insertion of the lma increased iop from   to   mmhg  p     but this did not exceed the preinduction value ',
#  'the ato therapy significantly reduced urine excretion of m  p    and nag  p    as compared to placebo ',
#  'apparently  the extracapsular lesions seen by trus are primarily nonmalignant ',
#  'to compare the efficacy and complication rates of two different techniques for inferior alveolar nerve blocks  ianb  ',
#  'at the end of the fifth year  the numbers reached      ',
#  'additional goals of this study are to identify groups for whom the intervention is particularly effective and to identify the therapeutic pathways that are vital in inducing clinical change ',
#  'visual activity patterns are not a sensitive measure of telescope benefit  but frequency of use patterns do change and appear to demonstrate a valid benefit of spectacle mounted telescopes for the visually impaired ',
#  'at  months after surgery the intervention group had better physical health   vs   p     fewer limitations in physical activity   vs   p     a greater reduction in the proportion of patients with a borderline diagnosis of anxiety    vs    p    and depression    vs    p     more planned ecgs    vs    p    and   fewer unplanned admissions    vs    p    ',
#  'ampicillin sodium is the active antimicrobial ingredient that can act on the phase of bacterial breeding and inhibit the biosynthesis of bacterial mucopeptide in the cell wall ',
#  'in the randomized  placebocontrolled doubleblind scami trial improvement in lvef up to  years was higher in bmc patients treated with a high cell number or without mo ',
#  'with separate guidelines used for diabetics    mm hg  and nondiabetics    mm hg   the proportions of women within the guidelines were   and    respectively ',
#  'the purpose of this study was to determine the effects of pushing techniques on mother and fetus in birth in this setting ',
#  'the bleeding score and the quality of life score improved ',
#  'although cilostazol was associated with side effects in approximately onethird of patients  most settled within  weeks  facilitating the continuation of therapy in    ',
#  'in posthoc analyses  combinations of other endpoints were also explored using the obrien rank sum test and showed statistically significant differences between elosulfase alfa qw and placebo favoring elosulfase alfa qw ',
#  'spearman correlations showed that acnc at t were positively related with acnc at t and negatively related with t to t acnc changes ',
#  'there is paucity in research on why adherence rates are low ',
#  'to evaluate the different stapling techniques with bacterial contamination  the drain fluid was examined for lysozyme activity ',
#  'ginger is as effective as mefenamic acid on pain relief in primary dysmenorrhea ',
#  'thrombolytic therapy may reduce the frequency of high intracranial pressure events ',
#  'we excluded smokers with current depression  but not those with a history of major depression ',
#  'both amniocentesis and cvs performed in the first trimester of pregnancy may impair antenatal lung growth ',
#  'glycemic response was evaluated  hours after each meal ',
#  'total projected accrual to the il randomization is anticipated to be  patients  and relapse and survival data remain blinded ',
#  'patients in groups  and  were treated conservatively ',
#  'across  experiments  the authors varied the health conditions people were asked to consider  either paraplegia  belowtheknee amputation  or partial blindness   the life domains they were asked to consider  the response mode with which they evaluated how each health condition would affect each life domain  whether subjects rated the health condition before and after considering life domains or only after  and whether subjects rated their own current quality of life first ',
#  'renalguard therapy is superior to sodium bicarbonate and nacetylcysteine in preventing contrastinduced acute kidney injury in highrisk patients ',
#  'pramipexole is highly efficacious in the reduction of plmi and in the improvement of subjective severity of rls and subjective sleep disturbance caused by the disorder ',
#  'we hypothesized an ordering effect in ki reduction  erlotinibsulindac  erlotinib  placebo ',
#  'the psa was targeted to gender and socioeconomic status  and designed to encourage patients to seek depression care or request information regarding depression ',
#  'cluster randomized trial ',
#  'we conducted a prospective  beforeandafter blinded study at two tertiary care institutions ',
#  'h pylori was considered eradicated if both histology and rapid urease test  six biopsies  antrumbody  were negative ',
#  'this effect was held true after adjustment for prognostic factors  hr     ci    p    ',
#  'in patients with nonvalvular atrial fibrillation  embolic stroke is thought to be associated with left atrial appendage  laa  thrombi ',
#  'during phase   a high rate of study discontinuations occurred due to intolerable side effects       and study nonadherence       ',
#  'that being presumed  this study asks the following questions     is there a difference in muscular strength when an individual holds a substance that is inimical to life processes  a poison solution   as compared to a substance that is essential for life  normal saline  ',
#  'an oral dispersible microtablet formulation of levodopacarbidopa   mg  lc  was developed for individualized repeated dosing ',
#  'iop measurements are performed with a reader unit held in front of the eye ',
#  'to investigate the effects of increased water intake on headache ',
#  'postinflammatory hyperpigmentation  pih  after laser treatment of hori nevus remains problematic ',
#  'randomized controlled trial ',
#  'the aim of this study was to evaluate the efficacy of a short course of oral prednisolone in nasal polyposis and to evaluate which  if any  clinical variables can predict treatment outcome in these patients ',
#  'this interaction may potentially be of some clinical significance when treating patients with chronic pain ',
#  'empirical therapy resulted in the lowest initial costs  but the highest rate of subsequent endoscopy ',
#  'sixty four patients enter the study  four were excluded because of systemic oral steroid therapy ',
#  'twentythree mechanically ventilated patients were randomly assigned to ventilation with either pcv or vcv at first  and then the other ',
#  'this study compared the pharmacokinetics  pharmacodynamics  and pharmacokineticpharmacodynamic  pkpd  profile of zaleplon  a new pyrazolopyrimidine hypnotic  with those of zolpidem and placebo ',
#  'blood lactate concentrations remained low    mmoll  throughout the study ',
#  'rates of successful ipsilateraldominant block using  ml of lidocaine   wt vol  primary outcome  and effects of patientcontrolled epidural analgesia using ropivacaine   wt vol  secondary outcomes  were evaluated ',
#  'the first scoring was performed by the nurse on a  scale ',
# ...
#  'this multicentre study randomized  patients with af scheduled for valve andor coronary surgery  group a  left atrial surgical ablation  n    vs group b  no ablation  n    ',
#  'current treatment guidelines suggest that several manualized treatments  including day hospital mentalizationbased treatment  mbtdh   are effective in these patients ',
#  'the primary efficacy variable at week  was the   response rate  as recommended by the assessments in ankylosing spondylitis  asas  working group ',
#  'the vdc with these regimens is not predictive of late virologic efficacy ',
#  'no statistically significant differences in liver cancer mortality were found comparing the presence and absence of any of the four intervention factors ',
#  'men with ed have a high incidence of comorbid conditions including cardiovascular disease  diabetes mellitus and benign prostatic hyperplasia ',
#  'it was suggested that small dose of oral theophylline combined with low dose of inhaled bdp might have the same effect on relief of clinical symptoms and bronchial responsiveness  without suppression on hpaa function  comparing with relatively higher dose of inhaled bdp ',
#  'sfgc is well tolerated when given by intravenous push without a test dose ',
#  'implant survival rates were   in the maxilla and   in the mandible ',
#  'despite the low number of patients it seems reasonable to state  that boosted idv may be used in significantly reduced dose ',
#  'the data suggest that statinfibrate combinations have a beneficial effect on all lipid parameters ',
#  'sixty adult patients undergoing abdominal surgery for cancer were randomly allocated to receive preoperative it   or  mg  plus postoperative pca morphine or postoperative pca morphine alone ',
#  'the test groups performed better after clinicians had gained some experience with the technique  and laserwelded titanium frameworks seem to be a viable alternative to conventional castings in the edentulous mandible ',
#  'however  this strategy was also accompanied by increased carriage of azithromycinresistant bacteria  the clinical consequences of which are uncertain  and will need careful monitoring and further study ',
#  'although there was some evidence of withdrawal symptoms being less marked in those patients allocated to dothiepin this was independent of any antidepressant effect as depression scores were lower in the placebo group in the early phase of withdrawal  p    ',
#  'the primary endpoint was the determination of antibiotics usage ',
#  'among all treatment groups  patients who had a mastectomy had the poorest physical functioning at registration  p    and at enrollment  p    ',
#  'isrctn ',
#  'the aim of the study was to investigate the feasibility of using an experimental model to determine the physiological effect of reflexology on stress ',
#  'a withinsubjects design was used in which a h recall and d weighed food records were completed within  wk by  mothers   nonhispanic white   nonhispanic black  and  hispanic  of moold infants or moold toddlers ',
#  'antropyloroduodenal motility  plasma ghrelin  cholecystokinin  glucagonlike peptide  peptide tyrosine tyrosine  insulin  glucagon  blood glucose  and appetite perceptions were measured ',
#  'hemoglobin  as a marker of blood loss  was measured preoperatively and perioperatively ',
#  'only one patient reported a febrile sensation  which was transient and mild in severity ',
#  'this study sought to identify individual difference moderators of the effects of written disclosure among women with chronic pelvic pain ',
#  'both procedures markedly improved glucose homeostasis  insulin  glp  and pyy levels increased similarly after either procedure ',
#  'application of higher positive endexpiratory pressure levels increased vt  dep and vtdep values and decreased vt  nondepvt  dep ratio  as compared with lower positive endexpiratory pressure  p    ',
#  'in nonallergic subjects with chronic obstructive lung disease short term treatment with high doses of inhaled or oral corticosteroids does not modify the bronchodilator response to salbutamol or ipratropium or the protection provided by either drug against histamine ',
#  'freeliving glycemic control was assessed for approximately  hours after the mmtt using continuous glucose monitoring ',
#  'we found evidence for the efficacy of an intervention addressing multiple risk factors for primary prevention at  year using framingham risk score report cards and telephone counselling ',
#  'postoperative iop was the mean iop of up to  visits including the split date      and  months  with   months  equaling the split date  ',
#  'the objective of the study was to assess potential pharmacokinetic interactions between delapril  an angiotensin conversion enzyme inhibitor  and manidipine  a calcium channel antagonist  prior to the development of a fixed combination drug product ',
#  'doxycycline treatment reduced aortic wall mmp and mmp messenger rna expression  p   and p    respectively   selectively suppressed neutrophil collagenase and gelatinase  mmp and mmp  protein levels  p   and    respectively   and increased protein levels of the protease inhibitors tissue inhibitor of metalloproteinase  and cystatin c  p    ',
#  'the injection treatment was also associated with a larger overall number of reported adverse events   vs  in the placebo treatment  ',
#  'although vitamin k has been shown to prevent prednisoloneinduced loss of bone mineral density of the lumbar spine in patients with chronic glomerulonephritis  the magnitude of this effect remains to be clarified ',
#  'the user centred design format was more efficient and usable than the cpoe test format even though training was provided for the latter ',
#  'the entomological evidence described here provides some evidence that lns could be usefully deployed as part of the vl control program ',
#  'carotid blood flow variations were detected by a probe directly inserted around the artery and monitored by an electromagnetic flowmeter ',
#  'the improvement in ppv pre  and postintervention was      confidence interval  ci    to    for the practices receiving both interventions  compared with a degradation of   pre  and postintervention    ci    to    for practices receiving only one intervention and a degradation of   for those receiving no intervention ',
#  'preterm infants treated cutaneously with soy oil showed better somatic growth than the control group ',
#  'clinicaltrialsgov nct ',
#  'influenza virus infectioninduced inflammatory responses are associated with fever and other symptoms ',
#  'there were no significant differences for secondary outcomes ',
#  'life table analysis did not show significant differences in mortality between the two groups ',
#  'patients were questioned for the subjective symptoms  overall improvement on appearance and sideeffects ',
#  'seventyfour women completed the baseline  phase and were randomized equally into two groups during the continuous phase ',
#  'baseline peep and fio were      cm ho and       respectively  mean    sd  ',
#  'the multivariate models were insufficient in predicting disability and pain  partly because disability and pain were also strongly associated with return to work ',
#  'to evaluate the glycemic control  lipid effects  and safety of pioglitazone in patients with type  diabetes mellitus ',
#  'seventyfive participants     were followed for  or more weeks on the trial ',
#  'the changes in lipid levels were similar between groups  p  ns  ',
#  'one dextransensitive patient     had a suspected allergic reaction after placebo ',
#  'h  p    ',
#  'five subjects in each group underwent curettage ',
#  'amylin  a secretory peptide of betacells  is the constituent peptide of islet amyloid  which is characteristic of niddm  and changes in amylin secretion in response to therapies may influence the rate of production of islet amyloid ',
#  'in a randomized  doubleblind  multicenter trial   maintenance lung transplant recipients received either everolimus  mg twice daily  n    or azathioprine  to  mgkgday  n    with cyclosporine and corticosteroids ',
#  'to evaluate in a controlled study the effects of highly purified senna extract on cell proliferation and crypt length in the entire colon and on p and bcl expression ',
#  'folstein mmse scores and neurologic function scores at baseline in combination with multiple other baseline variables were analyzed ',
#  'this is a randomized  doubleblind  doubledummy  activecontrolled  parallel  multicenter study ',
#  'the elimination of high initial saliva concentrations may diminish ecological disturbances of the mouth flora as well as removing the unpleasant taste of penicillin ',
#  'a randomized trial ',
#  'at initiation of the epidural the mean cervical dilatation was  cm in the early epidural group and  cm in the late group  p    ',
#  'peripheral venous blood was extracted before anesthesia induction  t   at the end of the surgery  t   and at  day  t  and  days  t  after the operation for measurement of serum s protein  nse and il levels using elisa ',
#  'we found no additional predictive value of replication capacity for virological or immunological responses  above what pss provides  in patients undergoing salvage arv treatment ',
#  'the secondary outcomes were  health status  from the medical outcomes study shortform item health survey  sf  v and  satisfaction  from the visual analogue scale ',
#  'public health professionals trained in health promotion and health protection must work together to effectively address the health concerns of this population ',
#  'freehb was     ul versus     ul postcpb for the sc and cc  respectively  p  ns  ',
#  'the nurse case manager followed written management algorithms under the direction of a family physician and an endocrinologist ',
#  'dysrhythmias  pq  qtc intervals and haemodynamics using the thermodilution technique were evaluated for up to  h after drug initiation ',
#  'children born to hivinfected mothers enrolled in the hiv prevention trial network trial  were tested for hiv infection at six intervals within the first year of life ',
#  'the size of the defect was found to be an independent predictor for recurrence  p    ',
#  'the distribution of positive and negative comments from the survey did not differ between the two diets  and the comments were mostly positive ',
#  'the main outcome measures were seal success  resistance to  mmhg intraluminal pressure for  min  and seal stability  burst pressure  ',
#  'the majority     of the buprenorphine patients transferred to alternateday dosing were maintained in alternateday dosing ',
#  'a year open randomized clinical study was designed ',
#  'primary  moderatevigorous physical activity  and secondary  intervention implementation data  health service use costs  intervention costs  health benefits  theoretical constructs  outcomes are assessed at baseline  months  end of intervention  and months  following month no contact  maintenance period  ',
#  'serum ldlcholesterol increased during the first week period and decreased during the second week period with both normal and enriched eggs ',
#  'urodynamic investigations provide an objective  quantitative evaluation of urinary function in patients with benign prostatic obstruction  bpo  ',
#  'the procedure of placing a catheter for continuous regional anaesthesia is often associated with fear and pain in the patient ',
#  'australian new zealand clinical trials registry  trial number   ',
#  'postterm pregnancy   or   weeks  ',
#  'after  months  the intervention group showed statistically significant improvements compared with the control group in the following measures  standing on one leg eyes open  p     tandem stance  p    and dizziness handicap inventory physical score  p    ',
#  'the subjects were instructed to chew the gums for  min over the course of  weeks ',
#  'the results demonstrated that the botoxtreated side with laser resurfacing improved significantly more than the contralateral area treated with saline and laser in diminishing periorbital rhytids as well as textural  pigmentation  and other features of periorbital skin aging ',
#  'treatment with rasagiline maintained motor function to baseline values for at least a year with significant benefits observed in all key pd motor symptoms ',
#  'to compare  in an unselected population of nulliparous pregnant women  the postnatal effect of prenatal supervised pelvic floor muscle training with written instructions on postpartum urinary incontinence  ui  ',
#  'a closed suction system  cs  maintains connection with the mechanical ventilator during tracheal suctioning and is claimed to limit loss in lung volume and oxygenation ',
#  'each period lasted for  consecutive days  days  and   ',
#  'bleeding complications in attreated patients with and without dic were higher compared with placebo  major bleeding rates    vs   for patients with dic  p      vs   for patients without dic  p    ',
#  'overall survival was not statistically different ',
#  'the patients were evaluated at two  eight  twelve  twentysix  and fiftytwo weeks with respect to the severity of pain  tenderness  swelling  wrist movement  grip strength  and symptoms and disability  which were assessed with the patient evaluation measure ',
#  'participants were assigned randomly to either an intervention or a control group ',
#  'significantly fewer major infectious complications     developed in patients randomized to the ied than patients in the isonitrogenous group     p    or the control group     p    ',
#  'nanofilledresin restorations with or without glass fiberlayering showed similarly high clinical performance ',
#  'the therapy of penetration needling on yang meridian of the back combined with electroacupuncture has the advantageous therapeutic effect on lower back myofascitis as compared with the medication of ibuprofen capsules  which can release pain and improve the functional disturbance effectively ',
#  'among completely sedentary individuals  intervention participants  selfperceived health status ratings were significantly lower than controls   or      ci      p    ',
#  'forty three and  patients were randomized to receive omeprazole  mg and rabeprazole  mg once daily  respectively  for at least  weeks ',
#  'gait analyses were normal for all dogs at  weeks ',
#  'an improved synergistic effect was achieved from concomitant np and rhendostatin compared with rhendostatin followed by np and single np ',
#  'lymphocyte numbers and thelper cells were significantly higher in the teai group at day   whereas no significant differences were detected among il  hladr  and postoperative clinical course ',
#  'the aim of this prospective  open  randomised study was to determine whether dydrogesterone was more effective than conservative management alone in preventing miscarriage in women with vaginal bleeding up to week  of pregnancy ',
#  'exercise is among the more successful treatments for this condition  however  the type and dosage of exercise that elicits the best results is not clearly defined ',
#  'motorized scooters provided to ambulatory persons with arthritis were used intermittently ',
#  'genotoxicity assays of colonic biopsy samples indicated a decreased exposure to genotoxins in polypectomized patients at the end of the intervention period ',
#  'fluconazole was significantly superior to placebo in eradicating clinical and mycologic symptoms of onychomycosis  both at the end of active treatment and at  months after treatment  p   for all efficacy measures  ',
#  'to compare serum betaestradiol  e   estrone  e   estrone sulfate  folliclestimulating hormone  luteinizing hormone  sex hormonebinding globulin  vaginal ph  and the vaginal maturation indices in women using a lowdose transdermal patch releasing  microg of e per day and a vaginal ring releasing  microg of e per day ',
#  'stable ihd patients from  october  to  september   identified using a registry of all angiography patients in ontario  canada ',
#  ...]

# %% [markdown]
# > converting the sentecnces into tokens

# %%
train_sentences = tokenizer.texts_to_sequences(train_sentences)
val_sentences = tokenizer.texts_to_sequences(val_sentences)

# %% [markdown]
# > lets pad the sentences

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
train_sentences = pad_sequences(train_sentences, maxlen = pad_len, padding = pad_style, truncating = trunc_style)
val_sentences = pad_sequences(val_sentences, maxlen = pad_len, padding = pad_style, truncating = trunc_style)

# %%
train_sentences.shape, val_sentences.shape
# Out:
# ((221186, 248), (28932, 248))

# %% [markdown]
# ### Create the Datapipeline

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_sentences, train_label_onehot))
val_ds = tf.data.Dataset.from_tensor_slices((val_sentences, val_label_onehot))

# %%
train_ds,val_ds
# Out:
# (<TensorSliceDataset element_spec=(TensorSpec(shape=(248,), dtype=tf.int32, name=None), TensorSpec(shape=(5,), dtype=tf.float64, name=None))>,
#  <TensorSliceDataset element_spec=(TensorSpec(shape=(248,), dtype=tf.int32, name=None), TensorSpec(shape=(5,), dtype=tf.float64, name=None))>)

# %%
train_ds = train_ds.shuffle(int(0.1*len(train_sentences))).batch(bs).prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.batch(bs).prefetch(tf.data.AUTOTUNE)

# %%
train_ds, val_ds
# Out:
# (<PrefetchDataset element_spec=(TensorSpec(shape=(None, 248), dtype=tf.int32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float64, name=None))>,
#  <PrefetchDataset element_spec=(TensorSpec(shape=(None, 248), dtype=tf.int32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float64, name=None))>)

# %% [markdown]
# ### Create Embedding Layer

# %%
from tensorflow.keras import layers

# %%
embed_layer = layers.Embedding(input_dim = vocab_size, output_dim = embed_len, input_length = pad_len)

# %% [markdown]
# > text the embedding layer

# %%
embed_layer(train_sentences[0])
# Out:
# <tf.Tensor: shape=(248, 16), dtype=float32, numpy=
# array([[ 0.02869818, -0.01960782,  0.04175866, ...,  0.02182112,
#         -0.04136328,  0.00414128],
#        [ 0.03557614, -0.00731556,  0.02285565, ..., -0.04692751,
#          0.047684  ,  0.0314167 ],
#        [-0.02349266,  0.04732765,  0.02178572, ..., -0.02010095,
#         -0.02582886,  0.00987246],
#        ...,
#        [-0.00650854, -0.03234841, -0.00045926, ...,  0.04235596,
#          0.00947078,  0.03146854],
#        [-0.00650854, -0.03234841, -0.00045926, ...,  0.04235596,
#          0.00947078,  0.03146854],
#        [-0.00650854, -0.03234841, -0.00045926, ...,  0.04235596,
#          0.00947078,  0.03146854]], dtype=float32)>

# %% [markdown]
# ### Create the callbacks

# %%
from helper_functions import create_model_checkpoint

# %%
train_ds
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 248), dtype=tf.int32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float64, name=None))>

# %% [markdown]
# ### Model 1
#
# Embedding + Global AvgPooling + Dense

# %%
classes = label_encoder.classes_
num_classes = len(classes)

# %%
inputs = tf.keras.Input(shape = [pad_len,], name = 'input_layer')
x = embed_layer(inputs)
x = layers.GlobalAveragePooling1D()(x)
x = layers.Dense(units = 32, activation = 'relu')(x)
outputs = layers.Dense(units = num_classes, activation = 'softmax')(x)
model_1 = tf.keras.Model(inputs, outputs, name = 'model_1')

model_1.compile(loss = tf.keras.losses.categorical_crossentropy,
                optimizer = tf.keras.optimizers.Adam(),
                metrics = ['accuracy'])

model_1.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 248)]             0
#
#  embedding (Embedding)       (None, 248, 16)           160000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 32)                544
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 160,709
# Trainable params: 160,709
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_1 = model_1.fit(train_ds,
                        epochs = 5, 
                        steps_per_epoch = int(len(train_ds)),
                        validation_data = val_ds,
                        validation_steps = int(len(val_ds)*0.25),
                        callbacks = [create_model_checkpoint(model_name = model_1.name)])
# Out:
# Epoch 1/5
# 6913/6913 [==============================] - 50s 7ms/step - loss: 0.8408 - accuracy: 0.6571 - val_loss: 0.6048 - val_accuracy: 0.7752
# Epoch 2/5
# 6913/6913 [==============================] - 30s 4ms/step - loss: 0.5903 - accuracy: 0.7773 - val_loss: 0.5657 - val_accuracy: 0.7949
# Epoch 3/5
# 6913/6913 [==============================] - 32s 5ms/step - loss: 0.5553 - accuracy: 0.7933 - val_loss: 0.5662 - val_accuracy: 0.7926
# Epoch 4/5
# 6913/6913 [==============================] - 32s 5ms/step - loss: 0.5332 - accuracy: 0.8039 - val_loss: 0.5369 - val_accuracy: 0.8107
# Epoch 5/5
# 6913/6913 [==============================] - 33s 5ms/step - loss: 0.5110 - accuracy: 0.8144 - val_loss: 0.5267 - val_accuracy: 0.8053

# %%
model_1.load_weights('checkpoints/model_1.h5')

# %%
model_1.evaluate(val_ds)
# Out:
# 905/905 [==============================] - 2s 2ms/step - loss: 0.5484 - accuracy: 0.8005
# [0.5484117865562439, 0.8004977107048035]

# %%
from helper_functions import calculate_results
def pred_and_show_result(model,val_ds = val_ds,val_labels = val_label_label_encoded):
  prob = model.predict(val_ds)
  pred = np.argmax(prob, axis = 1)
  res = calculate_results(y_true = val_labels, y_pred = pred)
  return res

# %%
result_1 = pred_and_show_result(model_1)
result_1
# Out:
# 905/905 [==============================] - 1s 1ms/step
# {'accuracy': 0.8004977187888843,
#  'precision': 0.7994580934005469,
#  'recall': 0.8004977187888843,
#  'f1': 0.799669917162396}

# %% [markdown]
# Model 2:
#
# Embedding + Conv1D + MaxPool + Flatten + Dense

# %%
inputs = tf.keras.Input(shape = [pad_len,], name = 'input_layer')
x = embed_layer(inputs)
x = layers.Conv1D(filters = 16, kernel_size = 5)(x)
x = layers.MaxPool1D()(x)
x = layers.Conv1D(filters = 32, kernel_size = 5)(x)
x = layers.MaxPool1D()(x)
x = layers.Flatten()(x)
x = layers.Dense(units = 16, activation = 'relu')(x)
outputs = layers.Dense(units = num_classes, activation = 'softmax')(x)
model_2 = tf.keras.Model(inputs, outputs, name = 'model_2')

model_2.compile(loss = tf.keras.losses.categorical_crossentropy,
                optimizer = tf.keras.optimizers.Adam(),
                metrics = ['accuracy'])

model_2.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 248)]             0
#
#  embedding (Embedding)       (None, 248, 16)           160000
#
#  conv1d_2 (Conv1D)           (None, 244, 16)           1296
#
#  max_pooling1d_1 (MaxPooling  (None, 122, 16)          0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 118, 32)           2592
#
#  max_pooling1d_2 (MaxPooling  (None, 59, 32)           0
#  1D)
#
#  flatten (Flatten)           (None, 1888)              0
#
#  dense_2 (Dense)             (None, 16)                30224
#
#  dense_3 (Dense)             (None, 5)                 85
#
# =================================================================
# Total params: 194,197
# Trainable params: 194,197
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_2 = model_2.fit(train_ds,
                        epochs = 5, 
                        steps_per_epoch = int(len(train_ds)),
                        validation_data = val_ds,
                        validation_steps = int(len(val_ds)*0.25),
                        callbacks = [create_model_checkpoint(model_name = model_2.name)])

model_2.load_weights('checkpoints/model_2.h5')

result_2 = pred_and_show_result(model_2)
result_2
# Out:
# Epoch 1/5
# 6913/6913 [==============================] - 40s 6ms/step - loss: 0.5121 - accuracy: 0.8123 - val_loss: 0.4980 - val_accuracy: 0.8216
# Epoch 2/5
# 6913/6913 [==============================] - 41s 6ms/step - loss: 0.4576 - accuracy: 0.8338 - val_loss: 0.4912 - val_accuracy: 0.8225
# Epoch 3/5
# 6913/6913 [==============================] - 54s 8ms/step - loss: 0.4241 - accuracy: 0.8465 - val_loss: 0.4924 - val_accuracy: 0.8320
# Epoch 4/5
# 6913/6913 [==============================] - 47s 7ms/step - loss: 0.3938 - accuracy: 0.8585 - val_loss: 0.4990 - val_accuracy: 0.8220
# Epoch 5/5
# 6913/6913 [==============================] - 40s 6ms/step - loss: 0.3662 - accuracy: 0.8695 - val_loss: 0.5277 - val_accuracy: 0.8147
# 905/905 [==============================] - 3s 3ms/step
# {'accuracy': 0.821201437854279,
#  'precision': 0.8169959767525753,
#  'recall': 0.821201437854279,
#  'f1': 0.8183513893778608}

# %% [markdown]
# Model 3
#
# - Embedding + LSTM + Dense

# %%
inputs = tf.keras.Input(shape = [pad_len,], name = 'input_layer')
x = embed_layer(inputs)
x = layers.LSTM(units = 64)(x)
x = layers.Dense(units = 16, activation = 'relu')(x)
outputs = layers.Dense(units = num_classes, activation = 'softmax')(x)
model_3 = tf.keras.Model(inputs, outputs, name = 'model_3')

model_3.compile(loss = tf.keras.losses.categorical_crossentropy,
                optimizer = tf.keras.optimizers.Adam(),
                metrics = ['accuracy'])

model_3.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 248)]             0
#
#  embedding (Embedding)       (None, 248, 16)           160000
#
#  lstm_1 (LSTM)               (None, 64)                20736
#
#  dense_5 (Dense)             (None, 16)                1040
#
#  dense_6 (Dense)             (None, 5)                 85
#
# =================================================================
# Total params: 181,861
# Trainable params: 181,861
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_3 = model_3.fit(train_ds,
                        epochs = 5, 
                        steps_per_epoch = int(len(train_ds)),
                        validation_data = val_ds,
                        validation_steps = int(len(val_ds)*0.25),
                        callbacks = [create_model_checkpoint(model_name = model_3.name)])

model_3.load_weights('checkpoints/model_3.h5')

result_3 = pred_and_show_result(model_3)
result_3
# Out:
# Epoch 1/5
# 6913/6913 [==============================] - 111s 15ms/step - loss: 1.4468 - accuracy: 0.3406 - val_loss: 1.4365 - val_accuracy: 0.3433
# Epoch 2/5
# 6913/6913 [==============================] - 92s 13ms/step - loss: 1.4457 - accuracy: 0.3430 - val_loss: 1.4370 - val_accuracy: 0.3433
# Epoch 3/5
# 6913/6913 [==============================] - 85s 12ms/step - loss: 1.4456 - accuracy: 0.3435 - val_loss: 1.4368 - val_accuracy: 0.3433
# Epoch 4/5
# 6913/6913 [==============================] - 107s 16ms/step - loss: 1.4456 - accuracy: 0.3436 - val_loss: 1.4375 - val_accuracy: 0.3433
# Epoch 5/5
# 6913/6913 [==============================] - 95s 14ms/step - loss: 1.4454 - accuracy: 0.3440 - val_loss: 1.4366 - val_accuracy: 0.3433
# 905/905 [==============================] - 4s 4ms/step
# {'accuracy': 0.3448430803262823,
#  'precision': 0.1189167500489188,
#  'recall': 0.3448430803262823,
#  'f1': 0.1768485138356328}

# %% [markdown]
# LSTM seems noot working

# %% [markdown]
# ### Model : 4
#
# - Embedding + Conv1D with diffrent parameters

# %%
inputs = tf.keras.Input(shape = [pad_len,], name = 'input_layer')
x = embed_layer(inputs)
x = layers.Conv1D(filters = 512, kernel_size = 3)(x)
x = layers.MaxPool1D()(x)
x = layers.Conv1D(filters = 124, kernel_size = 3)(x)
x = layers.MaxPool1D()(x)
x = layers.Flatten()(x)
x = layers.Dense(units = 16, activation = 'relu')(x)
outputs = layers.Dense(units = num_classes, activation = 'softmax')(x)

model_4 = tf.keras.Model(inputs, outputs, name = 'model_4')

model_4.compile(loss = tf.keras.losses.categorical_crossentropy,
                optimizer = tf.keras.optimizers.Adam(),
                metrics = ['accuracy'])

model_4.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 248)]             0
#
#  embedding (Embedding)       (None, 248, 16)           160000
#
#  conv1d_8 (Conv1D)           (None, 246, 512)          25088
#
#  max_pooling1d_7 (MaxPooling  (None, 123, 512)         0
#  1D)
#
#  conv1d_9 (Conv1D)           (None, 121, 124)          190588
#
#  max_pooling1d_8 (MaxPooling  (None, 60, 124)          0
#  1D)
#
#  flatten_2 (Flatten)         (None, 7440)              0
#
#  dense_12 (Dense)            (None, 16)                119056
#
#  dense_13 (Dense)            (None, 5)                 85
#
# =================================================================
# Total params: 494,817
# Trainable params: 494,817
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_4 = model_4.fit(train_ds,
                        epochs = 5, 
                        steps_per_epoch = int(len(train_ds)),
                        validation_data = val_ds,
                        validation_steps = int(len(val_ds)*0.25),
                        callbacks = [create_model_checkpoint(model_name = model_4.name)])

model_4.load_weights('checkpoints/model_4.h5')

result_4 = pred_and_show_result(model_4)
result_4
# Out:
# Epoch 1/5
# 6913/6913 [==============================] - 66s 9ms/step - loss: 0.4723 - accuracy: 0.8296 - val_loss: 0.4887 - val_accuracy: 0.8229
# Epoch 2/5
# 6913/6913 [==============================] - 61s 9ms/step - loss: 0.4190 - accuracy: 0.8500 - val_loss: 0.4987 - val_accuracy: 0.8237
# Epoch 3/5
# 6913/6913 [==============================] - 62s 9ms/step - loss: 0.3891 - accuracy: 0.8608 - val_loss: 0.5278 - val_accuracy: 0.8097
# Epoch 4/5
# 6913/6913 [==============================] - 61s 9ms/step - loss: 0.3623 - accuracy: 0.8704 - val_loss: 0.5374 - val_accuracy: 0.8108
# Epoch 5/5
# 6913/6913 [==============================] - 63s 9ms/step - loss: 0.3373 - accuracy: 0.8793 - val_loss: 0.5729 - val_accuracy: 0.8103
# 905/905 [==============================] - 6s 6ms/step
# {'accuracy': 0.8171574726945943,
#  'precision': 0.8148161639074278,
#  'recall': 0.8171574726945943,
#  'f1': 0.8154328979941129}

# %%
all_results = pd.DataFrame({model_1.name:result_1,
                            model_2.name:result_2,
                            model_3.name:result_3,
                            model_4.name:result_4}).transpose()

all_results.sort_values(by = 'f1', ascending = False, inplace = True)
all_results
# Out:
#          accuracy  precision    recall        f1
# model_2  0.821201   0.816996  0.821201  0.818351
# model_4  0.817157   0.814816  0.817157  0.815433
# model_1  0.800498   0.799458  0.800498  0.799670
# model_3  0.344843   0.118917  0.344843  0.176849

# %% [markdown]
# model_2 being the best model. lets save the model

# %%
model_2.load_weights('/content/checkpoints/model_2.h5')

# %%
model_2.save('best_model.h5')

# %%
loaded_model = tf.keras.models.load_model('best_model.h5')
loaded_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 248)]             0
#
#  embedding (Embedding)       (None, 248, 16)           160000
#
#  conv1d_2 (Conv1D)           (None, 244, 16)           1296
#
#  max_pooling1d_1 (MaxPooling  (None, 122, 16)          0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 118, 32)           2592
#
#  max_pooling1d_2 (MaxPooling  (None, 59, 32)           0
#  1D)
#
#  flatten (Flatten)           (None, 1888)              0
#
#  dense_2 (Dense)             (None, 16)                30224
#
#  dense_3 (Dense)             (None, 5)                 85
#
# =================================================================
# Total params: 194,197
# Trainable params: 194,197
# Non-trainable params: 0
# _________________________________________________________________

# %%
result_best_model = pred_and_show_result(loaded_model)
result_best_model
# Out:
# 905/905 [==============================] - 4s 4ms/step
# {'accuracy': 0.821201437854279,
#  'precision': 0.8169959767525753,
#  'recall': 0.821201437854279,
#  'f1': 0.8183513893778608}

# %% [markdown]
# End of the document
